# %% [markdown]
# # Report: Analysis of Particulate matter (PM 2.5) and (PM 10) in Nigeria(2020)
#
# This Analysis involves the calculation of PM 2.5 and PM 10 in Nigeria for the year 2020.
#
# ## Data Used:
# 1. The data used was obtained from ads copernicus with spatial resolution 0.1x0.1 degree in Nigeria for 2020.
# 2. It was downloded in 3hourly
#
# ## Methodology
# ### 1.Diurnal
# The diurnal data was obtained by averaging all the values for each hour of the days: 0:00, 3:00, 6:00, 9:00, 12:00, 15:00, 18:00, and 21:00, for the entire year to just one value for these hours. This process resulted in a single value for each hour
#
# ### 1. Monthly
# The monthly data was extracted using Microsoft Excel. Each month's data was calculated by averaging all the values for each hour. For example, in January, the values for 0:00, 3:00, 6:00, 9:00, 15:00, 18:00, and 21:00 were averaged to obtain a single value for each hour of the day. This process was repeated for every month.
#
# The files were individually extracted using Microsoft Excel and then grouped accordingly using this formula:
#
#                     Monthly= df.groupby("time").mean
#
# ### 2. Seasonal
# DJF,MAM,SON,JJA
# The average of DJF was obtained by summing all the values for these three months and finding their average.This process was repeated for every season.
#
# ## Result
# Diurnal observation: Two peaks (an increase in PM2.5 and PM10) were observed during peak morning hours (3:00 and 6:00 Hrs) and late evening (12:00 and 15:00Hrs). However, the percentage reduction remains almost constant throughout the day.
#
# Seasonal observation: We experience the highest PM concentration (2.5 and 10) in DJF, the dry season and the lowest in JJA,the wet season.
#
# Monthly observation: We experience the highest PM concentration (2.5 and 10) in February,dry season and the lowest in July, wet season.
#
# Overall, the relationship between PM2.5 and PM10 is not always linear some are simple, while others are complex because of the complex chemistry and atmospheric dynamic

# %%
#Analysis done include monthly,seasonal,diurnal variation over the year

# %% [markdown]
# ## Installing important libraries

# %%
#import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Reading out data

# %%
#calling out the 3 hourly PM 2.5 dataset obtained
df=pd.read_csv("/Users/Dell/Desktop/Personal work/PM 2.5 Nigeria.csv")
df.drop("#",axis=1,inplace=True)
df.head()

# %% [markdown]
# ## Data Preparation for Analysis:Cleaning and Formatting

# %%
#yearly 3 hourly

# %%
df=df.groupby("time", as_index=False).mean()
df.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16192\1530764401.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df=df.groupby("time", as_index=False).mean()
#        time         value     month
# 0   0:00:00  6.655301e-08  6.513661
# 1  12:00:00  3.868997e-08  6.513661
# 2  15:00:00  3.768881e-08  6.513661
# 3  18:00:00  4.848934e-08  6.513661
# 4  21:00:00  6.260383e-08  6.513661

# %%
plt.figure(figsize=(12,8))
plt.plot(df["time"],df["value"],color="orange")
plt.title("Diurnal variation of PM 2.5 in Nigeria(2020)")
plt.xlabel("time")
plt.ylabel("PM 2.5(µg/m3)")
# Out:
# Text(0, 0.5, 'PM 2.5(µg/m3)')

# %% [markdown]
# #### Note that each hour represents the mean of all data collected in the preceding 0:00,3:00,6:00,9:00,12:00,15:00,18:00,21:00

# %%
df1=pd.read_csv("/Users/Dell/Desktop/Personal work/monthly.csv")
df1.set_index("time",inplace=True)
df1.head()
# Out:
#                January           Feb          Marc         April  \
# time
# 0:00:00   1.090000e-07  1.180000e-07  9.320000e-08  6.240000e-08
# 3:00:00   1.130000e-07  1.190000e-07  9.380000e-08  6.120000e-08
# 6:00:00   1.170000e-07  1.200000e-07  9.300000e-08  6.010000e-08
# 9:00:00   1.020000e-07  1.100000e-07  6.950000e-08  4.550000e-08
# 12:00:00  7.770000e-08  1.020000e-07  6.660000e-08  4.000000e-08
#
#                    May          June          July        August  \
# time
# 0:00:00   4.720000e-08  4.060000e-08  3.080000e-08  3.110000e-08
# 3:00:00   4.620000e-08  4.010000e-08  3.030000e-08  3.180000e-08
# 6:00:00   4.520000e-08  3.970000e-08  2.740000e-08  3.220000e-08
# 9:00:00   3.230000e-08  2.760000e-08  1.610000e-08  1.890000e-08
# 12:00:00  2.440000e-08  2.470000e-08  1.190000e-08  1.490000e-08
#
#                   Sept           Oct           Nov           Dec
# time
# 0:00:00   4.460000e-08  6.490000e-08  7.620000e-08  8.280000e-08
# ...

# %%
plt.figure(figsize=(10,7))
sns.lineplot(df1,markers=True)
plt.legend(loc="upper left", bbox_to_anchor=(1,1))
plt.ylabel("PM 2.5(µg/m3)")
plt.title("Monthly variation of PM 2.5 in Nigeria(2020)")
# Out:
# Text(0.5, 1.0, 'Monthly variation of PM 2.5 in Nigeria(2020)')

# %%
df2=pd.read_csv("/Users/Dell/Desktop/Personal work/seasonal.csv")
df2.set_index("time",inplace=True)
df2.head()
# Out:
#                    DJF           MAM           JJA           SON
# time
# 0:00:00   1.032780e-07  6.758800e-08  3.417570e-08  6.189470e-08
# 3:00:00   1.070350e-07  6.706890e-08  3.406060e-08  6.460250e-08
# 6:00:00   1.098730e-07  6.610530e-08  3.308130e-08  6.544940e-08
# 9:00:00   8.809570e-08  4.908710e-08  2.085150e-08  3.725990e-08
# 12:00:00  6.895440e-08  4.368770e-08  1.716580e-08  2.601370e-08

# %%
plt.figure(figsize=(10,7))
sns.lineplot(df1)
plt.legend(loc="upper left", bbox_to_anchor=(1,1))
plt.ylabel("PM 2.5(µg/m3)")
plt.title("Seasonal analyis of PM 2.5 in Nigeria(2020)")
#plt.xlable("")
# Out:
# Text(0.5, 1.0, 'Seasonal analyis of PM 2.5 in Nigeria(2020)')

# %%
#analyzing pm 10

# %%
df=pd.read_csv("/Users/Dell/Desktop/Personal work/PM 10 Nigeria.csv")
df.drop("#",axis=1,inplace=True)
df.head()
# Out:
#        date      time         value  month
# 0  1/1/2020   0:00:00  7.010000e-08      1
# 1  1/1/2020   3:00:00  7.770000e-08      1
# 2  1/1/2020   6:00:00  8.630000e-08      1
# 3  1/1/2020   9:00:00  8.130000e-08      1
# 4  1/1/2020  12:00:00  4.360000e-08      1

# %%
df=df.groupby("time", as_index=False).mean()
df.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7440\3630566360.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df=df.groupby("time", as_index=False).mean()
#        time         value     month
# 0   0:00:00  8.799180e-08  6.513661
# 1  12:00:00  5.441170e-08  6.513661
# 2  15:00:00  5.251262e-08  6.513661
# 3  18:00:00  6.208880e-08  6.513661
# 4  21:00:00  8.197295e-08  6.513661

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=df,x="time",y="value",color="purple")
plt.title("Diurnal variation of PM 10 in Nigeria(2020)")
plt.xlabel("time")
plt.ylabel("PM 2.5(µg/m3)")
# Out:
# Text(0, 0.5, 'PM 2.5(µg/m3)')

# %%
#time is the index 
df.groupby("time").mean()
# Out:
#                  value     month
# time
# 0:00:00   8.799180e-08  6.513661
# 12:00:00  5.441170e-08  6.513661
# 15:00:00  5.251262e-08  6.513661
# 18:00:00  6.208880e-08  6.513661
# 21:00:00  8.197295e-08  6.513661
# 3:00:00   9.046721e-08  6.513661
# 6:00:00   9.141667e-08  6.513661
# 9:00:00   6.795847e-08  6.513661

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=df,x="time",y="value",color="purple")
plt.title("Diurnal variation of PM 10 in Nigeria(2020)")
plt.xlabel("time")
plt.ylabel("PM 2.5(µg/m3)")
# Out:
# Text(0, 0.5, 'PM 2.5(µg/m3)')

# %%
#Monthly analysis
df1=pd.read_csv("/Users/Dell/Desktop/Personal work/pm 10 monthly.csv")
df1.set_index("time",inplace=True)
df1.head()
# Out:
#                January      February         March         April  \
# time
# 0:00:00   1.380000e-07  1.480000e-07  1.210000e-07  8.170000e-08
# 3:00:00   1.440000e-07  1.500000e-07  1.230000e-07  8.080000e-08
# 6:00:00   1.490000e-07  1.530000e-07  1.230000e-07  7.960000e-08
# 9:00:00   1.370000e-07  1.560000e-07  9.560000e-08  6.280000e-08
# 12:00:00  1.030000e-07  1.430000e-07  9.260000e-08  5.740000e-08
#
#                    May          June          July        August  \
# time
# 0:00:00   6.350000e-08  5.470000e-08  4.290000e-08  4.370000e-08
# 3:00:00   6.250000e-08  5.440000e-08  4.240000e-08  4.470000e-08
# 6:00:00   6.140000e-08  5.410000e-08  3.850000e-08  4.540000e-08
# 9:00:00   4.540000e-08  3.880000e-08  2.290000e-08  2.680000e-08
# 12:00:00  3.540000e-08  3.550000e-08  1.740000e-08  2.120000e-08
#
#              September       October      November      December
# time
# 0:00:00   6.170000e-08  8.990000e-08  1.020000e-07  1.120000e-07
# ...

# %%
plt.figure(figsize=(10,7))
sns.lineplot(data=df1)
plt.legend(loc="upper left", bbox_to_anchor=(1,1))
plt.ylabel("PM 10(µg/m3)")
plt.title("Monthly variation of PM 10 in Nigeria(2020)")
# Out:
# Text(0.5, 1.0, 'Monthly variation of PM 10 in Nigeria(2020)')

# %%
#seasonal

# %%
df2=pd.read_csv("/Users/Dell/Desktop/Personal work/seasonal pm 10.csv")
df2.set_index("time",inplace=True)
df2.head()
# Out:
#                    DJF           MAM           JJA           SON
# time
# 0:00:00   1.326670e-07  8.870000e-08  4.710000e-08  8.450000e-08
# 3:00:00   1.383330e-07  8.880000e-08  4.720000e-08  8.860000e-08
# 6:00:00   1.423330e-07  8.800000e-08  4.600000e-08  9.020000e-08
# 9:00:00   1.212670e-07  6.790000e-08  2.950000e-08  5.440000e-08
# 12:00:00  9.390000e-08  6.180000e-08  2.470000e-08  3.860000e-08

# %%
plt.figure(figsize=(10,7))
sns.lineplot(data=df2)
plt.legend(loc="upper left", bbox_to_anchor=(1,1))
plt.ylabel("PM 10(µg/m3)")
plt.title("Seasonal analyis of PM 10 in Nigeria(2020)")
#plt.xlable("")
# Out:
# Text(0.5, 1.0, 'Seasonal analyis of PM 10 in Nigeria(2020)')
